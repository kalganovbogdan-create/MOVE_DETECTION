# %%
import numpy as np 
import matplotlib.pyplot as plt
from skimage.io import imread, imshow
from pathlib import Path

# %%
path = Path(r"C:\Users\Bogdan1\Pictures\kit.jpg")
image = imread(path)
imshow(image)
# Out:
# C:\Users\Bogdan1\AppData\Local\Temp\ipykernel_26532\1774720451.py:3: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(image)

# %%
image.shape
# Out:
# (1200, 675, 3)
